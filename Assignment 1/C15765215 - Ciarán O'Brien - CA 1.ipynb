# %%
# import the necessary packages:
import numpy as np
import cv2
from matplotlib import pyplot as plt
from matplotlib import image as image
import easygui

# %%
# Opening an image from a file:
textImage = cv2.imread("Text.jpg")

# %%
# Dsiplay the hostogram for the sample image
Values = textImage.ravel() 
plt.hist(Values,bins=256,range=[0,256]);

# %%
# No we look at the image using cv2's equalise fxn
greyTextImage = cv2.cvtColor(textImage,cv2.COLOR_BGR2GRAY)
eqHistImage = cv2.equalizeHist(greyTextImage)
plt.imshow(cv2.cvtColor(eqHistImage,cv2.COLOR_GRAY2BGR))

# %%
# Subplot setup
fig = plt.figure(figsize=(20,20))

ax1 = plt.subplot2grid((4,2), (0,0),)
ax2 = plt.subplot2grid((4,2), (0,1),)
ax3 = plt.subplot2grid((4,2), (1,0),)
ax4 = plt.subplot2grid((4,2), (1,1),)
ax5 = plt.subplot2grid((4,2), (2,0),)
ax6 = plt.subplot2grid((4,2), (2,1),)
ax7 = plt.subplot2grid((4,2), (3,0),)
ax8 = plt.subplot2grid((4,2), (3,1),)

# Assign each subplot with an 
ax1.imshow(textImage)

Values = textImage.ravel()
ax2.hist(Values,bins=256,range=[0,256])

greyTextImage = cv2.cvtColor(textImage,cv2.COLOR_BGR2GRAY)
eqHistImage = cv2.equalizeHist(greyTextImage)
ax3.imshow(cv2.cvtColor(eqHistImage,cv2.COLOR_GRAY2BGR))
ValuesEq = eqHistImage.ravel()
ax4.hist(ValuesEq,bins=256,range=[0,256])

# Jane's intensity correciton
Intentisiy = 255 * ( (greyTextImage-greyTextImage.min()) / (greyTextImage.max() - greyTextImage.min())  )
ax5.imshow(Intentisiy,cmap='gray')
ValuesIntenseEq = Intentisiy.ravel()
ax6.hist(ValuesIntenseEq,bins=256,range=[0,256])

# Testing clahe correction
# First create a clahe application layer
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
claheTextImage = clahe.apply(greyTextImage)
ax7.imshow(claheTextImage,cmap='gray')
ValuesClaheImage = claheTextImage.ravel()
ax8.hist(ValuesClaheImage,bins=256,range=[0,256])

plt.show()
