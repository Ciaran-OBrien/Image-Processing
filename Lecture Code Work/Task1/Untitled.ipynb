# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
# Opening an image from a file:
# Task 1.1
UltimateImage = cv2.imread("Ultimate.jpg")
OrignalUltimateImage = WheresWallyImage.copy()

# %%
# Convertimage to YUV
# Task 1.2
YUV = cv2.cvtColor(WheresWallyImage, cv2.COLOR_BGR2YUV)
fig = plt.figure(figsize=(30,30))
plt.imshow(YUV)

# %%
Y = YUV[:,:,0]

RGB = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)

# %%
y, u, v = cv2.split(YUV)

# %%
plt.figure(figsize=(15, 15))
plt.subplot(221)
plt.imshow(OrignalUltimateImage) 
plt.show() 
plt.figure(figsize=(15, 15))
plt.subplot(222)
YUV = cv2.cvtColor(YUV, cv2.COLOR_BGR2RGB)
plt.imshow(YUV)
plt.figure(figsize=(15, 15))
plt.subplot(223)
plt.imshow(y)
G = cv2.cvtColor(OrignalUltimateImage, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(15, 15))
plt.subplot(224)
plt.imshow(G)
plt.show()
