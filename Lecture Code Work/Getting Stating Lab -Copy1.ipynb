# %%
# Starter Pack for Image Processing

# (C) Dr Jane Courtney 2017

# import the necessary packages:
import numpy as np
import cv2
from matplotlib import pyplot as plt
from matplotlib import image as image
import easygui

# %%
# Opening an image from a file:
I = cv2.imread("ColourObjects.jpg")

# %%
Image2 = cv2.imread("hand_red_ball.png");

# %%
# Showing an image on the screen (MatPlotLib):
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
plt.imshow(I) 
plt.show()

# %%
# Converting to different colour spaces:
RGB = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
HSV = cv2.cvtColor(I, cv2.COLOR_BGR2HSV)
YUV = cv2.cvtColor(I, cv2.COLOR_BGR2YUV)
G = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)

# define range of blue color in HSV
lower_blue = np.array([110,50,50])
upper_blue = np.array([130,255,255])

# define range of red colour in HSV
lower_red = np.array([255, 127, 127])
upper_red = np.array([255, 0, 0])

mask = cv2.inRange(HSV, lower_red, upper_red)
res = cv2.bitwise_and(I,I, mask= mask)

plt.imshow('frame',Image2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0ad546b430f7> in <module>()
#      16 res = cv2.bitwise_and(I,I, mask= mask)
#      17
# ---> 18 plt.imshow('frame',Image2)
#
# c:\users\ciaran\appdata\local\programs\python\python35\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# c:\users\ciaran\appdata\local\programs\python\python35\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\users\ciaran\appdata\local\programs\python\python35\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5483         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5484                               filternorm=filternorm, filterrad=filterrad,
# -> 5485                               resample=resample, **kwargs)
#    5486
#    5487         im.set_data(X)
#
# c:\users\ciaran\appdata\local\programs\python\python35\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     822             filterrad=filterrad,
#     823             resample=resample,
# --> 824             **kwargs
#     825         )
#     826
#
# c:\users\ciaran\appdata\local\programs\python\python35\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     226         """
#     227         martist.Artist.__init__(self)
# --> 228         cm.ScalarMappable.__init__(self, norm, cmap)
#     229         self._mouseover = True
#     230         if origin is None:
#
# c:\users\ciaran\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cm.py in __init__(self, norm, cmap)
#     201         self.norm = norm
#     202         #: The Colormap instance of this ScalarMappable.
# --> 203         self.cmap = get_cmap(cmap)
#     204         #: The last colorbar associated with this ScalarMappable. May be None.
#     205         self.colorbar = None
#
# c:\users\ciaran\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     158         return name
#     159
# --> 160     if name in cmap_d:
#     161         if lut is None:
#     162             return cmap_d[name]
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
# Keeping a copy:
Original = I.copy()

# %%
# # Drawing a line:
cv2.line(img = I, pt1 = (200,200), pt2 = (500,600), color = (255,255,255), thickness = 5) 

# # Drawing a circle:
cv2.circle(img = I, center = (800,400), radius = 50, color = (0,0,255), thickness = -1)

# # Drawing a rectangle:
cv2.rectangle(img = I, pt1 = (500,100), pt2 = (800,300), color = (255,0,255), thickness = 10)

cv2.imshow('image',I)

# %%
# # Accessing a pixel's value:
B = I[400,800,0]
BGR = I[400,800]
print(B)
print (BGR)
# Out:
# 255
# [255 255 255]

# %%
# Setting a pixel's value:
I[400,800,0] = 255
cv2.imshow("image", I)
I[400,800] = (255,0,0)
cv2.imshow("image", I)
I[390:410,790:810] = (255,0,0)
cv2.imshow("image", I)
I[:,:,2] = 0
cv2.imshow("image", I)

# %%
def draw(event,x,y,flags,param): 
    if event == cv2.EVENT_LBUTTONDOWN: 
        cv2.circle(img = I, center = (x,y),radius = 5, color = (255,255,255), thickness = -1) 
        cv2.imshow("image", I) 

cv2.namedWindow("image") 
cv2.setMouseCallback("image", draw) 
cv2.imshow("image", I)
