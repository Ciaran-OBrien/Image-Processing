# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from matplotlib import image as image
import easygui

# %%
I = image.imread("download.jpg")

# %%
G = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)
Values = G.ravel() 

H = cv2.equalizeHist(G)
H = cv2.cvtColor(H,cv2.COLOR_GRAY2BGR)
plt.imshow(H)

# %%
def draw(evemt ,x, y, flags, param):

    cv2.imshow("image",draw)
    cv2.setMouseCallback("img",draw)
    while(True):
        k = cv2.waitKey(33)
        if k == -1:  # if no key was pressed, -1 is returned
            continue
        else:
            break
    cv2.destroyWindow('img')

# %%
fig, ax = plt.subplots()
ax.plot(2,2)
def onclick():
    plt.subplot(212)
    plt.imshow(img2)
    plt.show()



cid = fig.canvas.mpl_connect('button_press_event', onclick)

# %%
fig, ax = plt.subplots()
ax.plot(2,2)
def onclick():
    cv2.rectangle(img = I, pt1 = (x+201,x-201), pt2 = (x-201,x+201), color = (255,0,255), thickness = 10)
    cv2.imshow("image",draw)
    cv2.setMouseCallback("img",draw)
    while(True):
        k = cv2.waitKey(33)
        if k == -1:  # if no key was pressed, -1 is returned
            continue
        else:
            break
    cv2.destroyWindow('img')


cid = fig.canvas.mpl_connect('button_press_event', onclick)

# %%
plt.subplot(212)
plt.imshow(I)
plt.show()
